# %% [markdown]
# <a href="https://colab.research.google.com/github/fariya09ahmed-commits/Fariya-Ahmed/blob/main/2nd%20prg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#assg-1
age=int(input('Enter your age '))
if age >= 18:
  print("you are an old")
else:
  print("you are not an old")
# Out:
# Enter your age 24
# you are an old

# %%
#assg-2
number=int(input('Enter your number '))
if number >= 0:
  print("positive number")
elif number <= 0:
  print("negative number")
else:
  print("the number is zero")
# Out:
# Enter your number -3
# negative number

# %%
#assg-3
number=int(input('Enter your number'))
if number % 2 == 0:
  print("even number")
else:
  print("odd number")
# Out:
# Enter your number5
# odd number
