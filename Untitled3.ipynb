# %% [markdown]
# <a href="https://colab.research.google.com/github/fariya09ahmed-commits/Fariya-Ahmed/blob/master/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name="fariya"
age=24
is_student=True
height=5.2
print("Name:",name)
print("Age:",age)
print("student status:",is_student)
print("Height:",height)
# Out:
# Name: fariya
# Age: 24
# student status: True
# Height: 5.2
