# %% [markdown]
# <a href="https://colab.research.google.com/github/fariya09ahmed-commits/Fariya-Ahmed/blob/master/1st_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#assg-1
name="fariya"
age=24
favourite_color="green"
print("Name:",name)
print("Age:",age)
print("Favourite color:",favourite_color)
# Out:
# Name: fariya
# Age: 24
# Favourite color: green

# %%
#assg-2
name="fariya"
adress='faridpur'
age=24
mark=270.75
result=None
is_student=True
is_empolye=False
print(type(name))
print(type(adress))
print(type(age))
print(type(mark))
print(type(result))
print(type(is_student))
print(type(is_empolye))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'NoneType'>
# <class 'bool'>
# <class 'bool'>

# %%
#assg-3
length=7
width=5
area=length*width
perimeter=2*(length+width)
print(area)
print(perimeter)
# Out:
# 35
# 24

# %%
#assg-4
bangladeshifoods=["rice","fish","fuska","briyani","pitha"]
print(bangladeshifoods[0])
print(bangladeshifoods[4])
# Out:
# rice
# pitha

# %%
#assg-5
number=[5,12,15,17,21]
number.remove(15)
number.sort()
print(number)
# Out:
# [5, 12, 17, 21]

# %%
#assg-6
student={
    "name":"Fariya",
    "age":24,
    "university":"BUET",
    "course":["machine learning","graph theory","mathematical modeling","game theory"]}
print(student["name"])
print(student["age"])
print(student["university"])
print(student["course"][0])
student["phone"]="01537596923"
if "email" in student:
      print("Email found")
else:
      print("No email found")
      print(student["phone"])
# Out:
# Fariya
# 24
# BUET
# machine learning
# No email found
# 01537596923

# %%
#assg-7
bangladeshfamouseplace=("Sundorban","Cox's Bazar","Saint Martin")
single=(25.1630,)
print(bangladeshfamouseplace)
print(single)
# Out:
# ('Sundorban', "Cox's Bazar", 'Saint Martin')
# (25.163,)

# %%
#assg-8
colors={"red","green","orange","white","blue"}
print(colors)
colors.add("yellow")
colors.update(["blue","black"])
print(colors)
colors.remove("orange")
colors.discard("pear")
favourite_colors={"green","orange","pink"}
dress_colors={"white","blue","green"}
all_colors=favourite_colors|dress_colors
print(all_colors)
common=favourite_colors & dress_colors
print(common)
# Out:
# {'white', 'green', 'orange', 'red', 'blue'}
# {'white', 'green', 'orange', 'red', 'black', 'blue', 'yellow'}
# {'white', 'blue', 'green', 'orange', 'pink'}
# {'green'}

# %%
#ass-9
text="hello fariya"
print(text[0])
print(text[-1])
# Out:
# h
# a

# %%
#assg-10
a="hello"
b="bangladesh"
result=a+" "+b
print(result[0:2])
print(result[:8])
"hello bangladesh".upper()
# Out:
# he
# hello ba
# 'HELLO BANGLADESH'
