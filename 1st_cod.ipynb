# %% [markdown]
# <a href="https://colab.research.google.com/github/fariya09ahmed-commits/Fariya-Ahmed/blob/master/1st_cod.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#removing element in list
fruit=["apple","mango","banana","orange"]
fruit.remove("mango")
popped=fruit.pop()
print(fruit)
print(popped)
# Out:
# ['apple', 'banana']
# orange

# %%
#organinzing list
fruit=["orange","apple","banana","mango"]
fruit.sort()
print(fruit)
fruit.reverse()
print(fruit)
# Out:
# ['apple', 'banana', 'mango', 'orange']
# ['orange', 'mango', 'banana', 'apple']

# %%
#creating a dictionary key:valu
student={
    "name":"fariya",
    "age":24,
    "university":"BUET",
    "course":["python","data science","web development"]}
print(student["name"])
print(student["age"])
student["phone"]="01537596923"
print(student["university"])
print(student["course"][0])
print(student["phone"])
# Out:
# fariya
# 24
# BUET
# python
# 01537596923

# %%
#creating  tuple
coordinates=(10.5,20.8)
rgb_color=(255,0,128)
print(coordinates[0])
print(rgb_color[2])
print(len(rgb_color))
# Out:
# 10.5
# 128
# 3
